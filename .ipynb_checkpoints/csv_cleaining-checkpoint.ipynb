# %% [markdown]
# # CSV cleaning

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read data

# %%
tweets_df = pd.read_csv('french_wuhan_with_accounts.csv')
rtt_df = pd.read_csv('retweets.csv')

# %%
tweets_df.head()
# Out:
#                                    'id'          'author_id'  \
# 0  4cf9943a-0c79-11eb-8577-02420a00006f             18657350
# 1  54b589b8-0c79-11eb-8577-02420a00006f   814383841855045633
# 2  e49281dc-0c77-11eb-8577-02420a00006f            891464784
# 3  b58b95b6-0c79-11eb-8577-02420a00006f  1057778746839760896
# 4  9aeb11de-0c77-11eb-8577-02420a00006f            724288676
#
#    'author_username'  'authors'  'title'  \
# 0               None       None     None
# 1               None       None     None
# 2               None       None     None
# 3               None       None     None
# 4               None       None     None
#
#                                               'body'  'country'  'doc_type'  \
# 0  Ça se passe possiblement en Chine (ou un quart...       None     twitter
# 1  @Merovingien481 @XuluQen @Mediavenir Pour se f...       None     twitter
# 2  Ptdrrrrrr la frappe de Chine je suis morte htt...       None     twitter
# 3  @aliyya213s Que Dieu te pardonne 🙏. Genre il y...       None     twitter
# 4  « La frappe de Chine » ptdrrrr ils sont ravagé...     France     twitter
#
#    'language'    'publishing_date'  ...             'name'  \
# 0          fr  2020-10-04 16:28:42  ...  Véronique Meunier
# 1          fr  2020-10-04 15:27:36  ...         Nzonzimi 🌍
# 2          fr  2020-10-07 08:35:00  ...            Dounias
# 3          fr  2020-10-03 21:23:08  ...                🙏🙏🙏
# 4          fr  2020-10-07 11:49:10  ...                  ّ
#
#    'favourites_count'  'friends_count'  'language'.1        'location'  \
# 0               14942             2916          None  Montréal, Canada
# 1              134222              413          None   Belfort, France
# 2                 879              118          None               NaN
# 3                 721             1429          None               NaN
# 4               37849               99          None               NaN
#
#    'extracted_country'   'time_zone'         'created_at'  'listed_count'  \
# 0                   CA          None  2009-01-06 02:13:04              33
# 1                   FR          None  2016-12-29 08:13:33               0
# 2                 None          None  2012-10-19 17:46:58               0
# 3                 None          None  2018-10-31 23:38:00               2
# 4                   FR          None  2012-07-29 16:47:43               5
#
#     'project_tweet_count'
# 0                       1
# 1                      14
# 2                       1
# 3                       1
# 4                       1
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Data insight

# %% [markdown]
# ### Tweets csv

# %%
tweets_df.columns
# Out:
# Index([''id'', ' 'author_id'', ' 'author_username'', ' 'authors'', ' 'title'',
#        ' 'body'', ' 'country'', ' 'doc_type'', ' 'language'',
#        ' 'publishing_date'', ' 'main_document_id'', ' 'coordinates'',
#        ' 'place'', ' 'user_country'', ' 'retweet_count'', ' 'subject_classes'',
#        ' 'natural_key'', ' 'url'', ' 'document_urls'', ' 'base_popularity'',
#        ' 'popularity'', ' 'sentiment'', ''id'.1', ' 'description'',
#        ' 'followers_count'', ' 'screen_name'', ' 'global_tweet_count'',
#        ' 'name'', ' 'favourites_count'', ' 'friends_count'', ' 'language'.1',
#        ' 'location'', ' 'extracted_country'', ' 'time_zone'', ' 'created_at'',
#        ' 'listed_count'', ' 'project_tweet_count''],
#       dtype='object')

# %%
# author_id has nothing
print(np.unique(tweets_df[" 'author_username'"]))
# authors as nothing
print(np.unique(tweets_df[" 'authors'"]))
# title as nothing
print(np.unique(tweets_df[" 'title'"]))
# doctype is all twitter
print(np.unique(tweets_df[" 'doc_type'"]))
# language is all fr
print(np.unique(tweets_df[" 'language'"]))
# main_document_id has none
print(np.unique(tweets_df[" 'main_document_id'"]))
# subject_classes has none
print(np.unique(tweets_df[" 'subject_classes'"]))
# language.1 has none
print(np.unique(tweets_df[" 'language'.1"]))
# time_zone has none
print(np.unique(tweets_df[" 'time_zone'"]))

to_remove = [
    " 'author_username'",
    " 'authors'",
    " 'title'",
    " 'doc_type'",
    " 'language'",
    " 'main_document_id'",
    " 'subject_classes'",
    " 'language'.1",
    " 'time_zone'"
]

tweets_df = tweets_df.drop(columns = to_remove)
# Out:
# ['None']
# ['None']
# ['None']
# ['twitter']
# ['fr']
# ['None']
# ['None']
# ['None']
# ['None']

# %%
filtered_headers = [header.replace("'",'').replace(' ','') for header in tweets_df.columns]
d = {}
for i in range(len(tweets_df.columns)):
    d[tweets_df.columns[i]] = filtered_headers[i]
    
tweets_df = tweets_df.rename(columns = d)

# %%
tweets_df.head()
# Out:
#                                      id            author_id  \
# 0  4cf9943a-0c79-11eb-8577-02420a00006f             18657350
# 1  54b589b8-0c79-11eb-8577-02420a00006f   814383841855045633
# 2  e49281dc-0c77-11eb-8577-02420a00006f            891464784
# 3  b58b95b6-0c79-11eb-8577-02420a00006f  1057778746839760896
# 4  9aeb11de-0c77-11eb-8577-02420a00006f            724288676
#
#                                                 body country  \
# 0  Ça se passe possiblement en Chine (ou un quart...    None
# 1  @Merovingien481 @XuluQen @Mediavenir Pour se f...    None
# 2  Ptdrrrrrr la frappe de Chine je suis morte htt...    None
# 3  @aliyya213s Que Dieu te pardonne 🙏. Genre il y...    None
# 4  « La frappe de Chine » ptdrrrr ils sont ravagé...  France
#
#        publishing_date coordinates        place user_country  retweet_count  \
# 0  2020-10-04 16:28:42        None         None           CA              0
# 1  2020-10-04 15:27:36        None         None           FR              0
# 2  2020-10-07 08:35:00        None         None         None              0
# 3  2020-10-03 21:23:08        None         None         None              0
# 4  2020-10-07 11:49:10        None  Les Mureaux           FR              4
#
#            natural_key  ...   screen_name global_tweet_count  \
# 0  1312791769503928325  ...  Vero_Meunier              28314
# 1  1312776392053075976  ...      Nzonzimi              18234
# 2  1313759719249653760  ...     SassouwQb              14875
# 3  1312503476610457601  ...      hay_dera              21811
# 4  1313808582928932867  ...     Sergueyui              43848
#
#                 name  favourites_count  friends_count          location  \
# 0  Véronique Meunier             14942           2916  Montréal, Canada
# 1         Nzonzimi 🌍            134222            413   Belfort, France
# 2            Dounias               879            118               NaN
# 3                🙏🙏🙏               721           1429               NaN
# 4                  ّ             37849             99               NaN
#
#   extracted_country           created_at listed_count  project_tweet_count
# 0                CA  2009-01-06 02:13:04           33                    1
# 1                FR  2016-12-29 08:13:33            0                   14
# 2              None  2012-10-19 17:46:58            0                    1
# 3              None  2018-10-31 23:38:00            2                    1
# 4                FR  2012-07-29 16:47:43            5                    1
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Retweet csv

# %%
rtt_df.head()
# Out:
#                   'id'   'original_tweet_id'         'author_id'  \
# 0  1312881822297018368   1312880858869583873           451270384
# 1  1313859160769953792   1313856784210235400  724529113084637184
# 2  1313910967168835587   1313856784210235400  700386863333433349
# 3  1314585420810911746   1314542958335721473           191170947
# 4  1312758994046509056   1312738895558258688  972925879398608900
#
#        retweeted_date'  Unnamed: 4
# 0  2020-10-04 22:26:33         NaN
# 1  2020-10-07 15:10:08         NaN
# 2  2020-10-07 18:36:00         NaN
# 3  2020-10-09 15:16:02         NaN
# 4  2020-10-04 14:18:28         NaN

# %%
rtt_df = rtt_df.drop(columns = 'Unnamed: 4')

# %%
rtt_df.columns
# Out:
# Index([''id'', ' 'original_tweet_id'', ' 'author_id'', ' retweeted_date''], dtype='object')

# %%
filtered_headers = [header.replace("'",'').replace(' ','') for header in rtt_df.columns]
d3 = {}
for i in range(len(rtt_df.columns)):
    d3[rtt_df.columns[i]] = filtered_headers[i]
    
rtt_df = rtt_df.rename(columns = d3)

# %%
rtt_df.head()
# Out:
#                     id    original_tweet_id           author_id  \
# 0  1312881822297018368  1312880858869583873           451270384
# 1  1313859160769953792  1313856784210235400  724529113084637184
# 2  1313910967168835587  1313856784210235400  700386863333433349
# 3  1314585420810911746  1314542958335721473           191170947
# 4  1312758994046509056  1312738895558258688  972925879398608900
#
#         retweeted_date
# 0  2020-10-04 22:26:33
# 1  2020-10-07 15:10:08
# 2  2020-10-07 18:36:00
# 3  2020-10-09 15:16:02
# 4  2020-10-04 14:18:28

# %% [markdown]
# ### Joining tweets and retweets

# %%
original_tweets_id = []
author_ids = []
retweet_dates = []

groups = rtt_df.groupby("original_tweet_id").groups
for k in groups.keys():
    l_a = []
    l_r = []
    original_tweets_id.append(k)
    for index in groups[k]:
        line = df3.iloc[[index]]
        l_a.append(line["author_id"])
        l_r.append(line["retweeted_date"])
    author_ids.append(l_a)
    retweet_dates.append(l_r)

# %%
df_temp = pd.DataFrame()
df_temp['natural_key'] = original_tweets_id
df_temp['rtt_author_ids'] = author_ids
df_temp['retweet_dates'] = retweet_dates

# %%
df_temp = df_temp.set_index('natural_key')
tweets_df = tweets_df.set_index('natural_key')

# %%
df_final = tweets_df.join(df_temp)
df_final.to_csv('tweets_clean.csv', index = False)
